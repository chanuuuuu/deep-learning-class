# %% [markdown]
# # 지금까지 배운 것들
#
# 끝으로 지금까지 배운 것들에 대해서 정리해보는 시간을 가지려고 합니다.
#
# #### 1. Tensorflow
# #### 2. Keras
# #### 3. CNN
# #### 4. 전이학습과 파인튜닝

# %% [markdown]
# ## Tensorflow
#
#
# ### 1. 텐서의 개념
#
# - **shape**
#
#
# - **dtype**
#
#
# ### 2. 텐서의 자료형
#
# - **tf.constant**
#
#
# - **tf.Variable**
#
#
# ### 3. 텐서의 특징
#
# - 텐서가 가지는 값이 변경되는 것이 아닌, 변경된 값으로 새로운 텐서가 생성된다.
#
#
# - Graph mode를 사용하면, 내부 연산이 병렬화, 최적화되어 수행된다.
#
#
# ### 4. 레이어, 모델 구현하기
#
# - `tf.Module`
#
#
# - `__init__`
#
#
# - `__call__`

# %% [markdown]
# ## Keras
#
# ### 1. 레이어, 모델 구현하기
#
# - `tf.keras.Model`
#
#
# - `__init__`
#
#
# - `build`
#
#
# - `call`
#
#
# ### 2. 모델 구현 방법
#
# - **class subclassing**
#
#
# - **Functional API**
#
#
# - **Sequential API**
#
#
# ### 3. 모델 학습 및 평가하기
#
# - `compile()`
#
#
# - `fit()`
#
#
# - `evaluate()`
#
#
# ### 4. 모델 저장 및 로드하기
#
# - `.save()`
#
#
# - `tf.keras.models.load_model()`

# %% [markdown]
# ## CNN
#
#
# ### 1. `tf.data.Dataset`
#
# - `tf.keras.preprocessing.image_dataset_from_directory()`
#
#
# - `map()`
#
#
#
# ### 2. Data Augmentation
#
# - `map()`함수로 구현하기
#
#
# - *Layer*로 구현하기
#
#
# - `ImageDataGenerator` 클래스로 구현하기
#
#
# ### 3.  `tf.keras.Layers`
#
#
# - `Dense`
#
#
# - `Conv2D`
#
#
# - `MaxPooling2D`
#
#
# - `ReLU`
#
#
# - `BatchNormalization`
#
#
# ### 4. 기타 개념
#
#
# - `sigmoid`
#
#
# - `global max pooling`

# %% [markdown]
# ## 전이학습과 파인튜닝
#
#
# ### 1. 전이 학습
#
# - *Convolution Layer*
#
#
# - `trainable = False`
#
#
# - *Fully connected Layer*
#
# ### 2. 파인 튜닝
#
#
# - `trainable = True`
#
#
# - 매우 낮은 *learning rate*
